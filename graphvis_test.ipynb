# %%
# !apt install graphviz graphviz-dev -y
# !pip install networkx pydot pygraphviz
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'libgraphviz-dev' instead of 'graphviz-dev'
# The following additional packages will be installed:
#   adwaita-icon-theme fontconfig fontconfig-config fonts-dejavu-core
#   fonts-liberation gtk-update-icon-cache hicolor-icon-theme
#   humanity-icon-theme libann0 libatk1.0-0 libatk1.0-data libavahi-client3
#   libavahi-common-data libavahi-common3 libbsd0 libcairo2 libcdt5 libcgraph6
#   libcroco3 libcups2 libdatrie1 libfontconfig1 libgail-common libgail18 libgd3
#   libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common
#   libgraphite2-3 libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libgts-0.7-5
#   libgts-bin libgvc6 libgvc6-plugins-gtk libgvpr2 libharfbuzz0b libice6
#   libicu60 libjbig0 liblab-gamut1 libltdl7 libpango-1.0-0 libpangocairo-1.0-0
#   libpangoft2-1.0-0 libpathplan4 libpixman-1-0 librsvg2-2 librsvg2-common
#   libsm6 libthai-data libthai0 libtiff5 libwebp6 libx11-6 libx11-data libxau6
#   libxaw7 libxcb-render0 libxcb-shm0 libxcb1 libxcomposite1 libxcursor1
#   libxdamage1 libxdmcp6 libxdot4 libxext6 libxfixes3 libxi6 libxinerama1
#   libxml2 libxmu6 libxpm4 libxrandr2 libxrender1 libxt6 shared-mime-info
#   ubuntu-mono ucf x11-common
# Suggested packages:
#   gsfonts graphviz-doc cups-common libgd-tools gvfs librsvg2-bin
# The following NEW packages will be installed:
#   adwaita-icon-theme fontconfig fontconfig-config fonts-dejavu-core
#   fonts-liberation graphviz gtk-update-icon-cache hicolor-icon-theme
#   humanity-icon-theme libann0 libatk1.0-0 libatk1.0-data libavahi-client3
#   libavahi-common-data libavahi-common3 libbsd0 libcairo2 libcdt5 libcgraph6
#   libcroco3 libcups2 libdatrie1 libfontconfig1 libgail-common libgail18 libgd3
#   libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common
#   libgraphite2-3 libgraphviz-dev libgtk2.0-0 libgtk2.0-bin libgtk2.0-common
#   libgts-0.7-5 libgts-bin libgvc6 libgvc6-plugins-gtk libgvpr2 libharfbuzz0b
#   libice6 libicu60 libjbig0 liblab-gamut1 libltdl7 libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpathplan4 libpixman-1-0 librsvg2-2
#   librsvg2-common libsm6 libthai-data libthai0 libtiff5 libwebp6 libx11-6
#   libx11-data libxau6 libxaw7 libxcb-render0 libxcb-shm0 libxcb1
#   libxcomposite1 libxcursor1 libxdamage1 libxdmcp6 libxdot4 libxext6
#   libxfixes3 libxi6 libxinerama1 libxml2 libxmu6 libxpm4 libxrandr2
#   libxrender1 libxt6 shared-mime-info ubuntu-mono ucf x11-common
# 0 upgraded, 83 newly installed, 0 to remove and 57 not upgraded.
# Need to get 24.3 MB of archives.
# After this operation, 107 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxau6 amd64 1:1.0.8-1ubuntu1 [7556 B]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libbsd0 amd64 0.8.7-1ubuntu0.1 [41.6 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxdmcp6 amd64 1:1.1.2-3 [10.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb1 amd64 1.13-2~ubuntu18.04 [45.5 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libx11-data all 2:1.6.4-3ubuntu0.3 [114 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libx11-6 amd64 2:1.6.4-3ubuntu0.3 [571 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxext6 amd64 2:1.3.3-1 [29.4 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 ucf all 3.0038 [50.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-dejavu-core all 2.37-1 [1041 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 fonts-liberation all 1:1.07.4-7~18.04.1 [822 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 fontconfig-config all 2.12.6-0ubuntu2 [55.8 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfontconfig1 amd64 2.12.6-0ubuntu2 [137 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 fontconfig amd64 2.12.6-0ubuntu2 [169 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 x11-common all 1:7.7+19ubuntu7.1 [22.5 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libice6 amd64 2:1.0.9-2 [40.2 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsm6 amd64 2:1.2.2-1 [15.8 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxinerama1 amd64 2:1.1.3-1 [7908 B]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libicu60 amd64 60.2-3ubuntu3.1 [8054 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxml2 amd64 2.9.4+dfsg1-6.1ubuntu1.3 [663 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 shared-mime-info amd64 1.9-2 [426 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 hicolor-icon-theme all 0.17-2 [9976 B]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjbig0 amd64 2.1-3.1build1 [26.7 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libtiff5 amd64 4.0.9-5ubuntu0.4 [153 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-common all 2.36.11-2 [4536 B]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-0 amd64 2.36.11-2 [165 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gtk-update-icon-cache amd64 3.22.30-1ubuntu4 [28.3 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpixman-1-0 amd64 0.34.0-2 [229 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-render0 amd64 1.13-2~ubuntu18.04 [14.7 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-shm0 amd64 1.13-2~ubuntu18.04 [5600 B]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxrender1 amd64 1:0.9.10-1 [18.7 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo2 amd64 1.15.10-2ubuntu0.1 [580 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcroco3 amd64 0.6.12-2 [81.3 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 libthai-data all 0.1.27-2 [133 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdatrie1 amd64 0.2.10-7 [17.8 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 libthai0 amd64 0.1.27-2 [18.0 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpango-1.0-0 amd64 1.40.14-1ubuntu0.1 [153 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgraphite2-3 amd64 1.3.11-2 [78.7 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic/main amd64 libharfbuzz0b amd64 1.7.2-1ubuntu1 [232 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpangoft2-1.0-0 amd64 1.40.14-1ubuntu0.1 [33.2 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpangocairo-1.0-0 amd64 1.40.14-1ubuntu0.1 [20.8 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 librsvg2-2 amd64 2.40.20-2ubuntu0.2 [98.6 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 librsvg2-common amd64 2.40.20-2ubuntu0.2 [5064 B]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/main amd64 humanity-icon-theme all 0.6.15 [1250 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ubuntu-mono all 16.10+18.04.20181005-0ubuntu1 [149 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/main amd64 adwaita-icon-theme all 3.28.0-1ubuntu1 [3306 kB]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libann0 amd64 1.1.2+doc-6 [24.8 kB]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libcdt5 amd64 2.40.1-2 [19.6 kB]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libcgraph6 amd64 2.40.1-2 [40.8 kB]
# Get:49 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwebp6 amd64 0.6.1-2 [185 kB]
# Get:50 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxpm4 amd64 1:3.5.12-1 [34.0 kB]
# Get:51 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgd3 amd64 2.2.5-4ubuntu0.4 [119 kB]
# Get:52 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgts-0.7-5 amd64 0.7.6+darcs121130-4 [150 kB]
# Get:53 http://archive.ubuntu.com/ubuntu bionic/main amd64 libltdl7 amd64 2.4.6-2 [38.8 kB]
# Get:54 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libpathplan4 amd64 2.40.1-2 [22.6 kB]
# Get:55 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgvc6 amd64 2.40.1-2 [601 kB]
# Get:56 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgvpr2 amd64 2.40.1-2 [169 kB]
# Get:57 http://archive.ubuntu.com/ubuntu bionic/universe amd64 liblab-gamut1 amd64 2.40.1-2 [178 kB]
# Get:58 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxt6 amd64 1:1.1.5-1 [160 kB]
# Get:59 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxmu6 amd64 2:1.1.2-2 [46.0 kB]
# Get:60 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxaw7 amd64 2:1.0.13-1 [173 kB]
# Get:61 http://archive.ubuntu.com/ubuntu bionic/universe amd64 graphviz amd64 2.40.1-2 [601 kB]
# Get:62 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk1.0-data all 2.28.1-1 [2992 B]
# Get:63 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk1.0-0 amd64 2.28.1-1 [43.9 kB]
# Get:64 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libavahi-common-data amd64 0.7-3.1ubuntu1.2 [22.1 kB]
# Get:65 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libavahi-common3 amd64 0.7-3.1ubuntu1.2 [21.6 kB]
# Get:66 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libavahi-client3 amd64 0.7-3.1ubuntu1.2 [25.2 kB]
# Get:67 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcups2 amd64 2.2.7-1ubuntu2.8 [211 kB]
# Get:68 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-common all 2.24.32-1ubuntu1 [125 kB]
# Get:69 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcomposite1 amd64 1:0.4.4-2 [6988 B]
# Get:70 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxfixes3 amd64 1:5.0.3-1 [10.8 kB]
# Get:71 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcursor1 amd64 1:1.1.15-1 [19.8 kB]
# Get:72 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxdamage1 amd64 1:1.1.4-3 [6934 B]
# Get:73 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxi6 amd64 2:1.7.9-1 [29.2 kB]
# Get:74 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxrandr2 amd64 2:1.5.1-1 [18.1 kB]
# Get:75 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-0 amd64 2.24.32-1ubuntu1 [1769 kB]
# Get:76 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail18 amd64 2.24.32-1ubuntu1 [14.2 kB]
# Get:77 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail-common amd64 2.24.32-1ubuntu1 [112 kB]
# Get:78 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-bin amd64 2.36.11-2 [7864 B]
# Get:79 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libxdot4 amd64 2.40.1-2 [15.7 kB]
# Get:80 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgvc6-plugins-gtk amd64 2.40.1-2 [18.2 kB]
# Get:81 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgraphviz-dev amd64 2.40.1-2 [57.3 kB]
# Get:82 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-bin amd64 2.24.32-1ubuntu1 [7536 B]
# Get:83 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgts-bin amd64 0.7.6+darcs121130-4 [41.3 kB]
# Fetched 24.3 MB in 5s (4764 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package libxau6:amd64.
# (Reading database ... 17347 files and directories currently installed.)
# Preparing to unpack .../00-libxau6_1%3a1.0.8-1ubuntu1_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking libxau6:amd64 (1:1.0.8-1ubuntu1) ...
# Selecting previously unselected package libbsd0:amd64.
# Preparing to unpack .../01-libbsd0_0.8.7-1ubuntu0.1_amd64.deb ...
# Unpacking libbsd0:amd64 (0.8.7-1ubuntu0.1) ...
# 7Progress: [  1%] [..........................................................] 8Selecting previously unselected package libxdmcp6:amd64.
# Preparing to unpack .../02-libxdmcp6_1%3a1.1.2-3_amd64.deb ...
# Unpacking libxdmcp6:amd64 (1:1.1.2-3) ...
# 7Progress: [  2%] [#.........................................................] 8Selecting previously unselected package libxcb1:amd64.
# Preparing to unpack .../03-libxcb1_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb1:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package libx11-data.
# Preparing to unpack .../04-libx11-data_2%3a1.6.4-3ubuntu0.3_all.deb ...
# 7Progress: [  3%] [#.........................................................] 8Unpacking libx11-data (2:1.6.4-3ubuntu0.3) ...
# Selecting previously unselected package libx11-6:amd64.
# Preparing to unpack .../05-libx11-6_2%3a1.6.4-3ubuntu0.3_amd64.deb ...
# Unpacking libx11-6:amd64 (2:1.6.4-3ubuntu0.3) ...
# 7Progress: [  4%] [##........................................................] 8Selecting previously unselected package libxext6:amd64.
# Preparing to unpack .../06-libxext6_2%3a1.3.3-1_amd64.deb ...
# Unpacking libxext6:amd64 (2:1.3.3-1) ...
# 7Progress: [  5%] [##........................................................] 8Selecting previously unselected package ucf.
# Preparing to unpack .../07-ucf_3.0038_all.deb ...
# Moving old data out of the way
# Unpacking ucf (3.0038) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../08-fonts-dejavu-core_2.37-1_all.deb ...
# 7Progress: [  6%] [###.......................................................] 8Unpacking fonts-dejavu-core (2.37-1) ...
# Selecting previously unselected package fonts-liberation.
# Preparing to unpack .../09-fonts-liberation_1%3a1.07.4-7~18.04.1_all.deb ...
# Unpacking fonts-liberation (1:1.07.4-7~18.04.1) ...
# 7Progress: [  7%] [####......................................................] 8Selecting previously unselected package fontconfig-config.
# Preparing to unpack .../10-fontconfig-config_2.12.6-0ubuntu2_all.deb ...
# Unpacking fontconfig-config (2.12.6-0ubuntu2) ...
# Selecting previously unselected package libfontconfig1:amd64.
# Preparing to unpack .../11-libfontconfig1_2.12.6-0ubuntu2_amd64.deb ...
# 7Progress: [  8%] [####......................................................] 8Unpacking libfontconfig1:amd64 (2.12.6-0ubuntu2) ...
# Selecting previously unselected package fontconfig.
# Preparing to unpack .../12-fontconfig_2.12.6-0ubuntu2_amd64.deb ...
# Unpacking fontconfig (2.12.6-0ubuntu2) ...
# 7Progress: [  9%] [#####.....................................................] 8Selecting previously unselected package x11-common.
# Preparing to unpack .../13-x11-common_1%3a7.7+19ubuntu7.1_all.deb ...
# dpkg-query: no packages found matching nux-tools
# Unpacking x11-common (1:7.7+19ubuntu7.1) ...
# 7Progress: [ 10%] [#####.....................................................] 8Selecting previously unselected package libice6:amd64.
# Preparing to unpack .../14-libice6_2%3a1.0.9-2_amd64.deb ...
# Unpacking libice6:amd64 (2:1.0.9-2) ...
# Selecting previously unselected package libsm6:amd64.
# Preparing to unpack .../15-libsm6_2%3a1.2.2-1_amd64.deb ...
# 7Progress: [ 11%] [######....................................................] 8Unpacking libsm6:amd64 (2:1.2.2-1) ...
# Selecting previously unselected package libxinerama1:amd64.
# Preparing to unpack .../16-libxinerama1_2%3a1.1.3-1_amd64.deb ...
# Unpacking libxinerama1:amd64 (2:1.1.3-1) ...
# 7Progress: [ 12%] [######....................................................] 8Selecting previously unselected package libicu60:amd64.
# Preparing to unpack .../17-libicu60_60.2-3ubuntu3.1_amd64.deb ...
# Unpacking libicu60:amd64 (60.2-3ubuntu3.1) ...
# Selecting previously unselected package libxml2:amd64.
# Preparing to unpack .../18-libxml2_2.9.4+dfsg1-6.1ubuntu1.3_amd64.deb ...
# 7Progress: [ 13%] [#######...................................................] 8Unpacking libxml2:amd64 (2.9.4+dfsg1-6.1ubuntu1.3) ...
# Selecting previously unselected package shared-mime-info.
# Preparing to unpack .../19-shared-mime-info_1.9-2_amd64.deb ...
# Unpacking shared-mime-info (1.9-2) ...
# 7Progress: [ 14%] [########..................................................] 8Selecting previously unselected package hicolor-icon-theme.
# Preparing to unpack .../20-hicolor-icon-theme_0.17-2_all.deb ...
# Unpacking hicolor-icon-theme (0.17-2) ...
# 7Progress: [ 15%] [########..................................................] 8Selecting previously unselected package libjbig0:amd64.
# Preparing to unpack .../21-libjbig0_2.1-3.1build1_amd64.deb ...
# Unpacking libjbig0:amd64 (2.1-3.1build1) ...
# Selecting previously unselected package libtiff5:amd64.
# Preparing to unpack .../22-libtiff5_4.0.9-5ubuntu0.4_amd64.deb ...
# 7Progress: [ 16%] [#########.................................................] 8Unpacking libtiff5:amd64 (4.0.9-5ubuntu0.4) ...
# Selecting previously unselected package libgdk-pixbuf2.0-common.
# Preparing to unpack .../23-libgdk-pixbuf2.0-common_2.36.11-2_all.deb ...
# Unpacking libgdk-pixbuf2.0-common (2.36.11-2) ...
# 7Progress: [ 17%] [#########.................................................] 8Selecting previously unselected package libgdk-pixbuf2.0-0:amd64.
# Preparing to unpack .../24-libgdk-pixbuf2.0-0_2.36.11-2_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-0:amd64 (2.36.11-2) ...
# 7Progress: [ 18%] [##########................................................] 8Selecting previously unselected package gtk-update-icon-cache.
# Preparing to unpack .../25-gtk-update-icon-cache_3.22.30-1ubuntu4_amd64.deb ...
# No diversion 'diversion of /usr/sbin/update-icon-caches to /usr/sbin/update-icon-caches.gtk2 by libgtk-3-bin', none removed.
# No diversion 'diversion of /usr/share/man/man8/update-icon-caches.8.gz to /usr/share/man/man8/update-icon-caches.gtk2.8.gz by libgtk-3-bin', none removed.
# Unpacking gtk-update-icon-cache (3.22.30-1ubuntu4) ...
# Selecting previously unselected package libpixman-1-0:amd64.
# Preparing to unpack .../26-libpixman-1-0_0.34.0-2_amd64.deb ...
# Unpacking libpixman-1-0:amd64 (0.34.0-2) ...
# 7Progress: [ 19%] [###########...............................................] 8Selecting previously unselected package libxcb-render0:amd64.
# Preparing to unpack .../27-libxcb-render0_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-render0:amd64 (1.13-2~ubuntu18.04) ...
# 7Progress: [ 20%] [###########...............................................] 8Selecting previously unselected package libxcb-shm0:amd64.
# Preparing to unpack .../28-libxcb-shm0_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-shm0:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package libxrender1:amd64.
# Preparing to unpack .../29-libxrender1_1%3a0.9.10-1_amd64.deb ...
# 7Progress: [ 21%] [############..............................................] 8Unpacking libxrender1:amd64 (1:0.9.10-1) ...
# Selecting previously unselected package libcairo2:amd64.
# Preparing to unpack .../30-libcairo2_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo2:amd64 (1.15.10-2ubuntu0.1) ...
# 7Progress: [ 22%] [############..............................................] 8Selecting previously unselected package libcroco3:amd64.
# Preparing to unpack .../31-libcroco3_0.6.12-2_amd64.deb ...
# Unpacking libcroco3:amd64 (0.6.12-2) ...
# 7Progress: [ 23%] [#############.............................................] 8Selecting previously unselected package libthai-data.
# Preparing to unpack .../32-libthai-data_0.1.27-2_all.deb ...
# Unpacking libthai-data (0.1.27-2) ...
# Selecting previously unselected package libdatrie1:amd64.
# Preparing to unpack .../33-libdatrie1_0.2.10-7_amd64.deb ...
# 7Progress: [ 24%] [#############.............................................] 8Unpacking libdatrie1:amd64 (0.2.10-7) ...
# Selecting previously unselected package libthai0:amd64.
# Preparing to unpack .../34-libthai0_0.1.27-2_amd64.deb ...
# Unpacking libthai0:amd64 (0.1.27-2) ...
# 7Progress: [ 25%] [##############............................................] 8Selecting previously unselected package libpango-1.0-0:amd64.
# Preparing to unpack .../35-libpango-1.0-0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpango-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package libgraphite2-3:amd64.
# Preparing to unpack .../36-libgraphite2-3_1.3.11-2_amd64.deb ...
# 7Progress: [ 26%] [###############...........................................] 8Unpacking libgraphite2-3:amd64 (1.3.11-2) ...
# Selecting previously unselected package libharfbuzz0b:amd64.
# Preparing to unpack .../37-libharfbuzz0b_1.7.2-1ubuntu1_amd64.deb ...
# Unpacking libharfbuzz0b:amd64 (1.7.2-1ubuntu1) ...
# 7Progress: [ 27%] [###############...........................................] 8Selecting previously unselected package libpangoft2-1.0-0:amd64.
# Preparing to unpack .../38-libpangoft2-1.0-0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpangoft2-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# 7Progress: [ 28%] [################..........................................] 8Selecting previously unselected package libpangocairo-1.0-0:amd64.
# Preparing to unpack .../39-libpangocairo-1.0-0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpangocairo-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package librsvg2-2:amd64.
# Preparing to unpack .../40-librsvg2-2_2.40.20-2ubuntu0.2_amd64.deb ...
# 7Progress: [ 29%] [################..........................................] 8Unpacking librsvg2-2:amd64 (2.40.20-2ubuntu0.2) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../41-librsvg2-common_2.40.20-2ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.40.20-2ubuntu0.2) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package humanity-icon-theme.
# Preparing to unpack .../42-humanity-icon-theme_0.6.15_all.deb ...
# Unpacking humanity-icon-theme (0.6.15) ...
# 7Progress: [ 31%] [#################.........................................] 8Selecting previously unselected package ubuntu-mono.
# Preparing to unpack .../43-ubuntu-mono_16.10+18.04.20181005-0ubuntu1_all.deb ...
# Unpacking ubuntu-mono (16.10+18.04.20181005-0ubuntu1) ...
# Selecting previously unselected package adwaita-icon-theme.
# Preparing to unpack .../44-adwaita-icon-theme_3.28.0-1ubuntu1_all.deb ...
# Unpacking adwaita-icon-theme (3.28.0-1ubuntu1) ...
# 7Progress: [ 32%] [##################........................................] 8Selecting previously unselected package libann0.
# Preparing to unpack .../45-libann0_1.1.2+doc-6_amd64.deb ...
# Unpacking libann0 (1.1.2+doc-6) ...
# 7Progress: [ 33%] [###################.......................................] 8Selecting previously unselected package libcdt5.
# Preparing to unpack .../46-libcdt5_2.40.1-2_amd64.deb ...
# Unpacking libcdt5 (2.40.1-2) ...
# Selecting previously unselected package libcgraph6.
# Preparing to unpack .../47-libcgraph6_2.40.1-2_amd64.deb ...
# 7Progress: [ 34%] [###################.......................................] 8Unpacking libcgraph6 (2.40.1-2) ...
# Selecting previously unselected package libwebp6:amd64.
# Preparing to unpack .../48-libwebp6_0.6.1-2_amd64.deb ...
# Unpacking libwebp6:amd64 (0.6.1-2) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package libxpm4:amd64.
# Preparing to unpack .../49-libxpm4_1%3a3.5.12-1_amd64.deb ...
# Unpacking libxpm4:amd64 (1:3.5.12-1) ...
# 7Progress: [ 36%] [####################......................................] 8Selecting previously unselected package libgd3:amd64.
# Preparing to unpack .../50-libgd3_2.2.5-4ubuntu0.4_amd64.deb ...
# Unpacking libgd3:amd64 (2.2.5-4ubuntu0.4) ...
# Selecting previously unselected package libgts-0.7-5:amd64.
# Preparing to unpack .../51-libgts-0.7-5_0.7.6+darcs121130-4_amd64.deb ...
# 7Progress: [ 37%] [#####################.....................................] 8Unpacking libgts-0.7-5:amd64 (0.7.6+darcs121130-4) ...
# Selecting previously unselected package libltdl7:amd64.
# Preparing to unpack .../52-libltdl7_2.4.6-2_amd64.deb ...
# Unpacking libltdl7:amd64 (2.4.6-2) ...
# 7Progress: [ 38%] [######################....................................] 8Selecting previously unselected package libpathplan4.
# Preparing to unpack .../53-libpathplan4_2.40.1-2_amd64.deb ...
# Unpacking libpathplan4 (2.40.1-2) ...
# Selecting previously unselected package libgvc6.
# Preparing to unpack .../54-libgvc6_2.40.1-2_amd64.deb ...
# 7Progress: [ 39%] [######################....................................] 8Unpacking libgvc6 (2.40.1-2) ...
# Selecting previously unselected package libgvpr2.
# Preparing to unpack .../55-libgvpr2_2.40.1-2_amd64.deb ...
# Unpacking libgvpr2 (2.40.1-2) ...
# 7Progress: [ 40%] [#######################...................................] 8Selecting previously unselected package liblab-gamut1.
# Preparing to unpack .../56-liblab-gamut1_2.40.1-2_amd64.deb ...
# Unpacking liblab-gamut1 (2.40.1-2) ...
# 7Progress: [ 41%] [#######################...................................] 8Selecting previously unselected package libxt6:amd64.
# Preparing to unpack .../57-libxt6_1%3a1.1.5-1_amd64.deb ...
# Unpacking libxt6:amd64 (1:1.1.5-1) ...
# Selecting previously unselected package libxmu6:amd64.
# Preparing to unpack .../58-libxmu6_2%3a1.1.2-2_amd64.deb ...
# 7Progress: [ 42%] [########################..................................] 8Unpacking libxmu6:amd64 (2:1.1.2-2) ...
# Selecting previously unselected package libxaw7:amd64.
# Preparing to unpack .../59-libxaw7_2%3a1.0.13-1_amd64.deb ...
# Unpacking libxaw7:amd64 (2:1.0.13-1) ...
# 7Progress: [ 43%] [########################..................................] 8Selecting previously unselected package graphviz.
# Preparing to unpack .../60-graphviz_2.40.1-2_amd64.deb ...
# Unpacking graphviz (2.40.1-2) ...
# Selecting previously unselected package libatk1.0-data.
# Preparing to unpack .../61-libatk1.0-data_2.28.1-1_all.deb ...
# 7Progress: [ 44%] [#########################.................................] 8Unpacking libatk1.0-data (2.28.1-1) ...
# Selecting previously unselected package libatk1.0-0:amd64.
# Preparing to unpack .../62-libatk1.0-0_2.28.1-1_amd64.deb ...
# Unpacking libatk1.0-0:amd64 (2.28.1-1) ...
# 7Progress: [ 45%] [##########################................................] 8Selecting previously unselected package libavahi-common-data:amd64.
# Preparing to unpack .../63-libavahi-common-data_0.7-3.1ubuntu1.2_amd64.deb ...
# Unpacking libavahi-common-data:amd64 (0.7-3.1ubuntu1.2) ...
# 7Progress: [ 46%] [##########################................................] 8Selecting previously unselected package libavahi-common3:amd64.
# Preparing to unpack .../64-libavahi-common3_0.7-3.1ubuntu1.2_amd64.deb ...
# Unpacking libavahi-common3:amd64 (0.7-3.1ubuntu1.2) ...
# Selecting previously unselected package libavahi-client3:amd64.
# Preparing to unpack .../65-libavahi-client3_0.7-3.1ubuntu1.2_amd64.deb ...
# 7Progress: [ 47%] [###########################...............................] 8Unpacking libavahi-client3:amd64 (0.7-3.1ubuntu1.2) ...
# Selecting previously unselected package libcups2:amd64.
# Preparing to unpack .../66-libcups2_2.2.7-1ubuntu2.8_amd64.deb ...
# Unpacking libcups2:amd64 (2.2.7-1ubuntu2.8) ...
# 7Progress: [ 48%] [###########################...............................] 8Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../67-libgtk2.0-common_2.24.32-1ubuntu1_all.deb ...
# Unpacking libgtk2.0-common (2.24.32-1ubuntu1) ...
# 7Progress: [ 49%] [############################..............................] 8Selecting previously unselected package libxcomposite1:amd64.
# Preparing to unpack .../68-libxcomposite1_1%3a0.4.4-2_amd64.deb ...
# Unpacking libxcomposite1:amd64 (1:0.4.4-2) ...
# Selecting previously unselected package libxfixes3:amd64.
# Preparing to unpack .../69-libxfixes3_1%3a5.0.3-1_amd64.deb ...
# 7Progress: [ 50%] [#############################.............................] 8Unpacking libxfixes3:amd64 (1:5.0.3-1) ...
# Selecting previously unselected package libxcursor1:amd64.
# Preparing to unpack .../70-libxcursor1_1%3a1.1.15-1_amd64.deb ...
# Unpacking libxcursor1:amd64 (1:1.1.15-1) ...
# 7Progress: [ 51%] [#############################.............................] 8Selecting previously unselected package libxdamage1:amd64.
# Preparing to unpack .../71-libxdamage1_1%3a1.1.4-3_amd64.deb ...
# Unpacking libxdamage1:amd64 (1:1.1.4-3) ...
# Selecting previously unselected package libxi6:amd64.
# Preparing to unpack .../72-libxi6_2%3a1.7.9-1_amd64.deb ...
# 7Progress: [ 52%] [##############################............................] 8Unpacking libxi6:amd64 (2:1.7.9-1) ...
# Selecting previously unselected package libxrandr2:amd64.
# Preparing to unpack .../73-libxrandr2_2%3a1.5.1-1_amd64.deb ...
# Unpacking libxrandr2:amd64 (2:1.5.1-1) ...
# 7Progress: [ 53%] [##############################............................] 8Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../74-libgtk2.0-0_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# 7Progress: [ 54%] [###############################...........................] 8Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../75-libgail18_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../76-libgail-common_2.24.32-1ubuntu1_amd64.deb ...
# 7Progress: [ 55%] [###############################...........................] 8Unpacking libgail-common:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgdk-pixbuf2.0-bin.
# Preparing to unpack .../77-libgdk-pixbuf2.0-bin_2.36.11-2_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-bin (2.36.11-2) ...
# 7Progress: [ 56%] [################################..........................] 8Selecting previously unselected package libxdot4.
# Preparing to unpack .../78-libxdot4_2.40.1-2_amd64.deb ...
# Unpacking libxdot4 (2.40.1-2) ...
# Selecting previously unselected package libgvc6-plugins-gtk.
# Preparing to unpack .../79-libgvc6-plugins-gtk_2.40.1-2_amd64.deb ...
# 7Progress: [ 57%] [#################################.........................] 8Unpacking libgvc6-plugins-gtk (2.40.1-2) ...
# Selecting previously unselected package libgraphviz-dev.
# Preparing to unpack .../80-libgraphviz-dev_2.40.1-2_amd64.deb ...
# Unpacking libgraphviz-dev (2.40.1-2) ...
# 7Progress: [ 58%] [#################################.........................] 8Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../81-libgtk2.0-bin_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.32-1ubuntu1) ...
# 7Progress: [ 59%] [##################################........................] 8Selecting previously unselected package libgts-bin.
# Preparing to unpack .../82-libgts-bin_0.7.6+darcs121130-4_amd64.deb ...
# Unpacking libgts-bin (0.7.6+darcs121130-4) ...
# Setting up libgts-0.7-5:amd64 (0.7.6+darcs121130-4) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up libpathplan4 (2.40.1-2) ...
# Setting up libicu60:amd64 (60.2-3ubuntu3.1) ...
# 7Progress: [ 61%] [###################################.......................] 8Setting up liblab-gamut1 (2.40.1-2) ...
# Setting up libgtk2.0-common (2.24.32-1ubuntu1) ...
# 7Progress: [ 62%] [###################################.......................] 8Setting up libxdot4 (2.40.1-2) ...
# Setting up libjbig0:amd64 (2.1-3.1build1) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up fonts-dejavu-core (2.37-1) ...
# Setting up libgdk-pixbuf2.0-common (2.36.11-2) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up libdatrie1:amd64 (0.2.10-7) ...
# Setting up libtiff5:amd64 (4.0.9-5ubuntu0.4) ...
# 7Progress: [ 65%] [#####################################.....................] 8Setting up libbsd0:amd64 (0.8.7-1ubuntu0.1) ...
# Setting up fonts-liberation (1:1.07.4-7~18.04.1) ...
# 7Progress: [ 66%] [######################################....................] 8Setting up ucf (3.0038) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Setting up libxml2:amd64 (2.9.4+dfsg1-6.1ubuntu1.3) ...
# 7Progress: [ 67%] [######################################....................] 8Setting up libgraphite2-3:amd64 (1.3.11-2) ...
# Setting up libcroco3:amd64 (0.6.12-2) ...
# 7Progress: [ 68%] [#######################################...................] 8Setting up libatk1.0-data (2.28.1-1) ...
# Setting up libpixman-1-0:amd64 (0.34.0-2) ...
# Setting up libatk1.0-0:amd64 (2.28.1-1) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up libltdl7:amd64 (2.4.6-2) ...
# Setting up libann0 (1.1.2+doc-6) ...
# 7Progress: [ 70%] [########################################..................] 8Setting up shared-mime-info (1.9-2) ...
# Setting up libgts-bin (0.7.6+darcs121130-4) ...
# 7Progress: [ 71%] [#########################################.................] 8Setting up libthai-data (0.1.27-2) ...
# Setting up libxdmcp6:amd64 (1:1.1.2-3) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up x11-common (1:7.7+19ubuntu7.1) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# update-rc.d: warning: start and stop actions are no longer supported; falling back to defaults
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up hicolor-icon-theme (0.17-2) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up libcdt5 (2.40.1-2) ...
# Setting up libx11-data (2:1.6.4-3ubuntu0.3) ...
# 7Progress: [ 74%] [##########################################................] 8Setting up libxau6:amd64 (1:1.0.8-1ubuntu1) ...
# Setting up libavahi-common-data:amd64 (0.7-3.1ubuntu1.2) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up libcgraph6 (2.40.1-2) ...
# Setting up libwebp6:amd64 (0.6.1-2) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up fontconfig-config (2.12.6-0ubuntu2) ...
# Setting up libgvpr2 (2.40.1-2) ...
# 7Progress: [ 77%] [############################################..............] 8Setting up libharfbuzz0b:amd64 (1.7.2-1ubuntu1) ...
# Setting up libthai0:amd64 (0.1.27-2) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up libice6:amd64 (2:1.0.9-2) ...
# Setting up libavahi-common3:amd64 (0.7-3.1ubuntu1.2) ...
# 7Progress: [ 79%] [#############################################.............] 8Setting up libxcb1:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libfontconfig1:amd64 (2.12.6-0ubuntu2) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up libsm6:amd64 (2:1.2.2-1) ...
# Setting up libxcb-render0:amd64 (1.13-2~ubuntu18.04) ...
# 7Progress: [ 81%] [##############################################............] 8Setting up libx11-6:amd64 (2:1.6.4-3ubuntu0.3) ...
# Setting up libxcomposite1:amd64 (1:0.4.4-2) ...
# Setting up libxcb-shm0:amd64 (1.13-2~ubuntu18.04) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libxpm4:amd64 (1:3.5.12-1) ...
# Setting up libxt6:amd64 (1:1.1.5-1) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up libxrender1:amd64 (1:0.9.10-1) ...
# Setting up libavahi-client3:amd64 (0.7-3.1ubuntu1.2) ...
# 7Progress: [ 84%] [################################################..........] 8Setting up fontconfig (2.12.6-0ubuntu2) ...
# Regenerating fonts cache... done.
# Setting up libcups2:amd64 (2.2.7-1ubuntu2.8) ...
# 7Progress: [ 85%] [#################################################.........] 8Setting up libxdamage1:amd64 (1:1.1.4-3) ...
# Setting up libxext6:amd64 (2:1.3.3-1) ...
# 7Progress: [ 86%] [#################################################.........] 8Setting up libxfixes3:amd64 (1:5.0.3-1) ...
# Setting up libgdk-pixbuf2.0-0:amd64 (2.36.11-2) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libgdk-pixbuf2.0-bin (2.36.11-2) ...
# Setting up libgd3:amd64 (2.2.5-4ubuntu0.4) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up libxmu6:amd64 (2:1.1.2-2) ...
# Setting up gtk-update-icon-cache (3.22.30-1ubuntu4) ...
# 7Progress: [ 89%] [###################################################.......] 8Setting up libxcursor1:amd64 (1:1.1.15-1) ...
# Setting up libpango-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up libxrandr2:amd64 (2:1.5.1-1) ...
# Setting up libxi6:amd64 (2:1.7.9-1) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up libxaw7:amd64 (2:1.0.13-1) ...
# Setting up libcairo2:amd64 (1.15.10-2ubuntu0.1) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up libxinerama1:amd64 (2:1.1.3-1) ...
# Setting up libpangoft2-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# 7Progress: [ 93%] [#####################################################.....] 8Setting up libpangocairo-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libgvc6 (2.40.1-2) ...
# Setting up librsvg2-2:amd64 (2.40.20-2ubuntu0.2) ...
# 7Progress: [ 94%] [######################################################....] 8Setting up librsvg2-common:amd64 (2.40.20-2ubuntu0.2) ...
# Setting up graphviz (2.40.1-2) ...
# Setting up adwaita-icon-theme (3.28.0-1ubuntu1) ...
# 7Progress: [ 95%] [#######################################################...] 8update-alternatives: using /usr/share/icons/Adwaita/cursor.theme to provide /usr/share/icons/default/index.theme (x-cursor-theme) in auto mode
# Setting up libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Setting up libgail18:amd64 (2.24.32-1ubuntu1) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up libgail-common:amd64 (2.24.32-1ubuntu1) ...
# Setting up libgvc6-plugins-gtk (2.40.1-2) ...
# 7Progress: [ 97%] [########################################################..] 8Setting up humanity-icon-theme (0.6.15) ...
# Setting up libgraphviz-dev (2.40.1-2) ...
# 7Progress: [ 98%] [########################################################..] 8Setting up libgtk2.0-bin (2.24.32-1ubuntu1) ...
# Setting up ubuntu-mono (16.10+18.04.20181005-0ubuntu1) ...
# 7Progress: [ 99%] [#########################################################.] 8Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# Processing triggers for libgdk-pixbuf2.0-0:amd64 (2.36.11-2) ...
#
# 78Collecting networkx
#   Downloading networkx-2.5.1-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 14.3 MB/s eta 0:00:01
# Collecting pydot
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting pygraphviz
#   Downloading pygraphviz-1.6.zip (117 kB)
#      |████████████████████████████████| 117 kB 33.3 MB/s eta 0:00:01
# Requirement already satisfied: decorator<5,>=4.3 in /usr/local/lib/python3.6/dist-packages (from networkx) (4.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.6/dist-packages (from pydot) (2.4.7)
# Building wheels for collected packages: pygraphviz
#   Building wheel for pygraphviz (setup.py) ... done
#   Created wheel for pygraphviz: filename=pygraphviz-1.6-cp36-cp36m-linux_x86_64.whl size=155071 sha256=a38bd838930120a4c15693bb2f9640309adf2a5a35bcb7d8e542fca4579e06da
#   Stored in directory: /root/.cache/pip/wheels/ae/dd/00/72ba3f6cec9d5c207e8dde77052acf6c27a58afefa0775ce04
# Successfully built pygraphviz
# Installing collected packages: pygraphviz, pydot, networkx
# Successfully installed networkx-2.5.1 pydot-1.4.2 pygraphviz-1.6
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %% [markdown]
# ## networkx のGraphを表示

# %%
import networkx as nx

# %%
G = nx.Graph()
G.add_edges_from([(1, 2), (1, 3)])
G.add_node("spam")       # adds node "spam"
list(nx.connected_components(G))

sorted(d for n, d in G.degree())

nx.clustering(G)
# Out:
# {1: 0, 2: 0, 3: 0, 'spam': 0}

# %%
from networkx.drawing.nx_pydot import write_dot
pos = nx.nx_agraph.graphviz_layout(G)
nx.draw(G, pos=pos)
write_dot(G, 'file.dot')

# %%
import pydot

graphs = pydot.graph_from_dot_file('file.dot')
graph = graphs[0]

# %% [markdown]
# ## Keras のモデルを表示

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
model = Sequential()
model.add(Dense(units=64, activation='relu', input_dim=100))
model.add(Dense(units=10, activation='softmax'))

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model.png')
